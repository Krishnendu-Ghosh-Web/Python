# %%
from PIL import Image,ImageChops
img1,img2=Image.open('Dadu1.jpg'),Image.open('Dadu2.jpg')
diff=ImageChops.difference(img1, img2)
if diff.getbbox():
   diff.show()
ImageChops.invert(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=941x1280>
